# %% [markdown]
# ### 10Apr25 Readings
# #### Meet The Trans Scholar Fighting Against The Campaign For Out Trans Military Service (2013)
# - Spade suggests that the fight for trans equality in the military was not pushed for by the trans community seems to be spearheaded by Col. Jennifer Natalya Pritzker, a billionaire heir to the Hyatt Hotel fortune
#     - "Colonel Pritzker, along with 10 other members of her family, are listed in the Forbes list of the "400 Richest Americans."
#     - Spade points out that the military issue is not the primary issue trans people are facing or advocating for yet it is the primary one discussed in the media (at the time of writing)
#         - "one very wealthy individual has picked this issue and is funding advocacy about it — putting more money toward trans military inclusion than is currently devoted to any other trans issue"
# - the issue
#     - Spade doesn't seem critical of trans military service members but the way this issue distracts and detracts from more pressing issues
#     - the sociopolitical backlash and fallout from this discussion falls also on those less contentious issues which trans rights activists are fighting for
#     - the campaign is also explicitly pro military and relies on the same rhetoric that has been used to justify the military's existence and expansion
#     - Spade suggests better uses of time and money would be continuing 15 years of fighting against poverty and criminalization in trans communities
# - Spade doesn't state it explicitly, but the article does frame Jennifer Pritzker's investment and advocacy as almost false flag feeling
#     - even if not intentionally a false flag, Spade makes a strong argument for it having the same effect
#         - the military is an almost holy and sacrosanct institution in the US and issues of military service have a heightened emotional resonance and sensitivity
#             - criticism of the military and the military-industrial complex is often met with extreme emotional backlash
#                 - Pritzker's campaign ties trans advocacy to what would be seen as perversions of "patriotism" and other "American values"
#         - "Anti-trans sentiment will be stirred up with patriotic fervor, and the rigorous, often local work we have been doing for decades to gain access to homeless shelters, drug treatment programs, and schools will be set back. Those who are most vulnerable will bear the brunt of the violence that ensues. Trans youth in foster care group homes and juvenile prisons, marginally housed trans people surviving in shelters and on the street, and others who are already easy targets for violence will feel the pain as the cops, parole officers and low-level bureaucrats who already control their lives take out their aroused aggressions on them."
# - "What makes sense for trans politics is to be aligned with anti-war and anti-military movements worldwide. We have nothing to gain for being the new poster children for a U.S. military branded as inclusive because it lets women serve in combat and has openly LGBT service members. This is shoddy window dressing for the realities of U.S. militarism, which is bad for the world and certainly bad for populations, like women and LGBT people, who are targets of sexual and gender violence."
#
# #### Patriotic And Proud Of Their Identities, Kansas City's Transgender Veterans Look To The Future
# - President Obama lifted the ban on transgender individuals serving openly in the military in 2016

# %% [markdown]
# ### 11Apr25 Class
# - first article
#     - one wealthy donor is pushing for open trans service
#     - poverty and criminalization are the actual issues we should be focused on
#     - military inclusion does not largely move these milestones forward
# - second article
#     - do positive trans service members' accounts negate the arguments of the first article?
#         - needs of the many vs needs of the few
#         - you can be against the military but still know that it exists and that people are in it
#             - i.e. just because we can't make it go away yet doesn't mean we should let it be racist, sexist, transphobic, etc.
#         - relationship contextualization
#             - "the military" isn't a monolith
#                 - as we see elsewhere, people may accept a person they know but not truly recognize them as a part of or representative of the group
#                     - the person you love is "an exception"
#             - service members and military leaders don't necessarily agree with the regulations
#                 - i.e. for many, the concern is probably more about mission readiness than who's trans
#                 - the regulations are largely set by congress, the president, political appointees, and to some degree public opinion
#                     - tldr; Seaman Timmy is trans, Captain Sarah doesn't care about the regulations, she's just trying to get the mission done and probably cares about Timmy

# %% [markdown]
# ### Assignment 3: Newscast
# - find an article about a current event from the last 5 years
# - pick a form of protest which addressed that issue directly
# - make a 3-4 minute video (newscast style) about the event and the protest
#     - describe the persecution and activist response
#     - analyze how the activism challenged the persecution
#     - intersectionaly interrogate whether the activism itself perpetuates other forms of oppression
#         - if not, highlight how it did a good job
# - additionally, include a bibliography/works cited document
# - other notes
#     - a script is recommended
#     - min time 2:45, max time 4:15
#     - can also do an alternative format covering following a similar rubric
#         - podcast or paper
#         - 900-1200 word news article
#
#
# ### Instructions and Rubric
#
# **Instructions**
# This assignment is designed to engage with the world that surrounds you from a slightly different perspective: one that is particularly focused upon LGBTQ activism. Battles over and about sexuality are happening all around us, all the time. Groups of sexual minorities are constantly fighting back against their persecution and discrimination. This activism can be transformational but also reinforce other forms of oppression (often without thought or intention).
#
# Use Google news searches or library database searches to find a news article about an LGBTQ current event from within the last 5 years. Using the news article as a jumping off point, do a bit more investigating into the issue you’ve chosen. Then pick a group or form of protest that addressed the issue directly. Finally, you will create a 3 to 4-minute video (much like a newscast segment) that does the following:
# - Describes the persecution and an activist response to the issue
# - Analyzes how the activism challenges the initial oppression
# - Deploys an intersectional analysis to interrogate whether the activism rearticulates other forms of oppression. If it does, explore how and in what ways it affirms other forms of oppression. If it does not, how do the activists involved accomplish their activism without relying on the oppression of others?
#
# In addition to the video, you must also upload a bibliography of your news source and any other research you drew from in the making of your newscast.
#
# This assignment hones your researching and critical thinking skills, particularly around identifying positionality and intersectional analysis. This assignment can also expand the ways you think about activism and spark ideas about how to change the world for the better. Intersectional activism is necessary but also HARD to do!
#
#
# **Rubric**
#
# **Identify and explain your chosen current event: 20%**
# This is largely a summary of your chosen current event. However, you also need to provide some larger context about the time and place relating to your choice.
#
# **Identify and explain an activist response or strategy: 20%**
# Here, you should not just describe what activists do, but assess the strategy behind it. Why did they choose that kind of response? Were other options considered? Are you focusing on one group’s response that was coordinating with other groups to give a more dynamic response? How was the activism received? What changes occurred as a result?
#
# **Intersectional Analysis: 25%**
# Even well-intentioned activists make mistakes, have ways to grow, and can be oppressors of others. In fact, existing in the world without reinforcing and benefitting from/experiencing oppression of others is VERY HARD for all of us all the time. This is a chance to really explore how intentional, strategic, and unintentional oppression happens. Look for ways in which activists made assumptions about either other activists or those they were protesting. Was the activism accessible for people with different physical capabilities? Did a gay or lesbian group decide to leave transgender issues off their agenda? Was there an assumption about race or wealth? Once you identify these forms of oppression, go deeper and try to discern if this was done intentionally. If so, was it out of malice, ignorance, strategy? Was it done unintentionally? What can be learned from that?
#
# **Newscast composition: 15%**
# Just because this isn’t a written assignment does not mean that it needs to be any less structured or argument driven than your other assignments. Plan out how you will address all the requirements of the prompt. You might consider making an outline, or even a script. Speak clearly and slowly enough so that I can understand you, please! Remember that the video should be between 3 and 4 minutes long; points will be taken off if your video is shorter than 2.75 minutes or longer than 4.25 minutes.
#
# **Forward Thinking: 10%**
# Finally, make some suggestions to future activists about how they might avoid reinforcing other forms of oppression.
#
# **Cite your sources: 10%**
# Provide a full citation for each source you reference in your video and submit it as a Works Cited/Bibliography in addition to your video.

# %% [markdown]
# ### 13Apr25 Readings
# #### What is Homonationalism?
# - the term is sometimes used derisively to describe any campaign for LGBTQ rights that could be coopted by nationalist or militaristic agendas
# - it is not a political position to be identified with, it is a structure through which we can analyze the ways in which LGBTQ rights are often framed and deployed
# - in Terrorist Assemblages, Jasbir Puar argued against the notion that the state is solely heteronormative and excludes queer individuals at all times and in all ways
#     - in Rethinking Homonationalism, Puar goes on to say that homonationalism is exemplified by how queer acceptance has become "a barometer by which the right to and capacity for national sovereignty is evaluated"
#         - this means that in some way or other, all LGBTQ rights campaigns uphold some ideals of social progress and act on the assumption that western nation states are capable of accepting and benefiting all people from all groups
#         - Puar argues that this is impossible as these states are built upon granting privileges to certain groups, necessitating that they be taken away from others
#             - e.g. the fight for and granting of marriage equality legitimize and entrench the normative ideal of marriage between two people
#             - e.g. a state granting trans citizens the right to change their identity on a passport legitimizes the state's ability to control and surveil its citizens, to control movement between borders, and to deport racialized minorities
# - it is difficult not to recreate homonationalist discourses whenv discussing current events such as Trump's push to ban trans servicemembers from the military
#     - i.e. it can be difficult to decouple support from trans people in the military from support for the military itself
#         - "trans people are just as good at killing brown people overseas as cis people."
# #### Welcoming the World? Hospitality, Homonationalism, and the London 2012 Olympics
# - the London 2012 Olympics were framed as a celebration of diversity and inclusion but only a specific subset of identities were included
#     - inclusivity was largely limited to homonormative identities
#         - e.g. middle class, "respectable" couples, affluent consumers
# - The olympic games are not only a sporting event but also a massive marketing and city transformation project
#     - hosting the olympics leads to the displacement of marginalized communities
#         - these are generally the communities that are advertised as being helped by the olympics when the decision is made to host
# - homonationalism at play
#     - the LGBTQ-friendly image was tied to a narrative of British exceptionalism
#         - the UK was portrayed as a global leader in civility and progress
#     - this positioned the UK "against" other countries that were not as accepting of LGBTQ identities
#     - the narrative was also tied to Islamaphobic undertones
#         - suggested that East London's Muslim communities were intolerant and needed reform
# - exclusion and regulation of queer spaces
#     - transgressive sexual cultures were marginalized or directly targeted by policing
#     - sex workers, particularly Eastern European migrant workers, were vilified in the media as a threat
#         - despite little to no evidence of an increase in trafficking or exploitation
#         - crackdowns on sex work intensified leading up to the Olympic games
# - neoliberal urbanism
#     - the Olympics tend to be used to accelerate gentrification
#         - the games are often used to justify the displacement of marginalized communities
#             - this is often framed as a positive development with wording like "urban renewal" or "clean-up" efforts
#     - the fantasy image of "unity in diversity" is painted over actual exclusion and urban inequality
#     - sexual diversity was commodified
#         - it is celebrated when profitable, erased when disruptive

# %% [markdown]
# ### 14Apr25 Class
# - think pair share
#     - How does cosmopolitan globalism affect marginalized people and places, such as the LGBTQ+ community in london in preparation for the 2012 Olympics?
#         - events like the Olympics give an excuse for gentrification under the guise of more palatable terms
#             - "urban renewal" or "clean-up"
#         - cosmpolitan globalism allows powerful groups to define and profit off of homonormative ideals
#         - it also allows them to quietly exclude and erase those who do not fit the mold
#             - a lot of trans exclusion
#         - commodification of identities via rainbow capitalism
#         - cosmopolitan globalism claims to erase borders and boundaries but it actually creates new ones
#             - i.e. the "acceptable" queer identities are now defined by the state and other powerful entities
#                 - this is a form of homonationalism
#         - further marginalizes those who are already marginalized due to the influx of attendees
#     - What do Hubbard and Wilkinson mean when they argue that "the type of narrative surrounding campaigns for global gay rights can easily slip into a language of neo-imperialism, with Western nations depicted as leading the way"?
#         - in western coutries, we are bombarded with media depicting other parts of the world as less developed, less civilized, and less accepting
#             - hence we are primed to accept the idea that we are better than the people "over there" [gestures vaguely] who are basically barbarians who would be lucky to have our rights
#                 - from here, its a hop, skip, and a jump to the idea that we should be "helping" them... with bombs and guns
#         - framing of the west as the "good" and "civilized" place
#             - "West is best" and the western savior complex
#             - pushing athletes to come out and move to the UK
#             - "we are going to civilize the savages"
#         - **the West defines what is cosmopolitan**
#         - tldr, when that is the language you are born into, molded by, and constantly immersed in, it is actually hard **not** to use it
#     - How does homonationalism relate to homonormativity?
#         - homonormative identities tend to fall within the bounds of what is acceptable to the state
#             - i.e. they are not threatening to the status quo
#         - homonormativity and homonationalism are tied together in that they both rely on the idea that there is a "right" way to be queer
#             - what is normatively acceptable is largely defined by the state and other powerful entities that work in tandem with the state
#             - as such, these norms tend to support the state and its interests
#         - homonationalism forces homonormativity onto other populations through imperialism
#         - preferentially benefits white, cis, middle class, able bodied, etc. individuals
# - overall thoughts
#     - queerness becomes a pawn
#         - it is utilized different ways in different contexts
#             - e.g. in the Olympics, Britain tried to leverage how "progressive" it is for financial and political gain
#         - these decisions are made to manipulate relationships
#             - to appease the public
#             - to benefit or appease partners of the state
#             - as a slight to other countries
#     - governments focus on controlling their citizens
#         - atrocities are often ignored unless it is politically expedient to address them
#             - e.g. gay nigerian men being stoned to death not being reported on but when it occurs in Iran, it becomes news because the US is trying to vilify Iran
#         - once a government legalizes something, they can control it
#             - once marriage is legal, the government gets to say what that means
#             - when a minority gets a right to something, the majority, through the government, generally gets a right to define, police, and surveil it
#     - gentrification
#         - you can remove the undesirable minorities who don't make you money and replace them with desirable minorities who do
#             - pacifies while continuing the oppression
#         - creates infighting within minority groups
#         - vilification of queer sex workers, particularly prostitution
#             - this did not apply to "acceptable" sex work such as strip clubs
#                 - this was used to define what was acceptable and what was not

# %% [markdown]
# ### 18Apr25 Class
# - settler colonialism
#     - sexual and gender variance has existed in many indigenous cultures
#     - missionaries such as Joseph-Francois Lafitau worked to erase these variations in the 16 and 1700s
#     - later, laws were passed to further enforce heterosexual gender binaries
#         - e.g. Residential Schools and the Indian Act
#     - in this way, queer native identities were some of the first targets of settler colonialism
#         - stamping out any gender nonconformity and religious practices
#     - Simpson pushes back on the notion that there was a "shift" from "brute force" to "disciplinary education to try and *break* Native communities, languages, and cultural knowledges"
#         - moving the violence to a residential school setting isn't a shift, it is a continuation of the same violence
#         - it makes the violence more palatable to the settler state and society
#             - now it is clinical "educational" and "civilizing"
#         - it also allowed the state to distance itself from the violence
#             - Simpson notes the lack of statistical data available from the residential schools
#             - "kill the indian, save the man"
# - Religion, law, science, media (the pillars of society)
#     - the Indian Act and similar laws were used to define and control Native identities
#         - policed Native identities, who could be recognized as Native, who could run for chief and council, etc.
#     - christianity was also used to define and control Native identities
#     - anthropologists came in to "study" Native identities
#         - this was often framed as a way to "preserve" Native cultures
#         - in reality, it was a way to control and define Native identities
#             - researchers projected their own biases and beliefs onto Native cultures
#     - the pillars of society are built and maintained by non-native people but they act on native people
# - grounded normativity
#     - as defined by Benjamin Joseph Kapron
#         - 1. humans are interrelated with the more-than-human world
#         - 2. interrelationality demands that humans develop ethical relationships with others
#         - 3. these ethical relationships can be learned and enacted through engagement with the more-than-human world
# - thought experiment: What would our lives look like if gender and sexual variance was accepted without question/how do we get there?
#     - queer stigma has to be erased
#     - people have to have privacy to explore their identities
#     - extends to both societal and individual levels
#     - requires believing people
#     - cultural compassion
#     - can you have a box on a form without it being a judgement call on those who are or are not in the box?
#     - sexualization would change
#         - without enforcement of the binary, people might to feel new and surprising things
#     - drag would have to be redefined
#         - if there is no femininity or masculinity to parody, what is drag?
#         - it would likely shift but likely not disappear
#     - people would be a lot more well adjusted
#         - studies indicate that androgynous people tend to be happier and healthier
#         - a lot less isolation and loneliness
#             - for queer people not wanting to be persecuted for being queer
#             - for straight people not wanting to be persecuted for being queer
#         - we can focus on policing whether affection and intimacy are consensual
#             - not whether they are heteronormative
#         - increased openness and acceptance
#             - if creativity is no longer queer-coded, everyone can
#                 - make art
#                 - wear what they want
#                 - pursue whatever field of study interests them
#                     - i.e. nursing wouldn't be seen as a "feminine" profession and STEM wouldn't be seen as a "masculine" profession

# %% [markdown]
# ### 20Apr25 Readings
# #### Sexual and Gender Diversity in Native America and the Pacific Islands
# - multiple gender and sexual identities have existed in Native cultures on mainland North America and the Pacific Islands
#     - european explorers often noted the prevalence of "hermaphrodites" and "sodomites" within these cultures
#     - europeans lacked both context and language to understand these identities
#     - the term "berdache" was used to describe identities which did not fit within the European binary
#         - this term is now considered derogatory and is not used by Native people
#         - in 1990, the term "Two-Spirit" was coined to describe identities balancing or combining male and female qualities
# - two-spirit
#     - prior to the arrival of Europeans, many Native cultures had their own terms and concepts for these identities
#         - for some, two spiritedness was noted in childhood, some held ceremonies, and some staged ritual tests to determine gender identity
#     - male two spirits often fell into intermediate gender roles, working hides, conducting burial rites, and serving as healers and ceremony leaders
#         - some ceremonial functions were reserved for two spirits
#     - there is less evidence for females engaged in men's activities
#         - it is worth noting that Euro-American anthropology tends to overlook these sorts of identities
#         - women also often engaged in male pursuits without being labeled as two-spirited
#     - two spirits generally formed relationships with non-two-spirit individuals of the same sex
#         - these relationships were seen as equally valid to their heterosexual counterparts
# - little was recorded of Hawai'i's mahu, men who performed women's work and formed relationships with other men
#     - oral traditions credit them with important roles in society including healing, caretaking, and leading hula dance traditions
#     - aikane relationships were distinct from this and held sexual connotations
#         - these tended to but were not required to be between men of different ages and/or social status
#         - most men with aikane were bisexual and married women as well
# - a recent revival
#     - in the past 50 or so years, there has been a resurgence of interest in two-spirit, mahu, and similar identities
#         - natives seek to reclaim their identities and traditions after centuries of erasure and forced assimilation

# %% [markdown]
# ### 21Apr25 Class
# - the US has over 500 recognized native tribes
#     - each tribe has its own language, culture, and traditions
#     - there is no single "native" identity
#         - the term "native" is often used as a catch-all term for all indigenous peoples in North America
# - outdated historical terms used by Europeans
#     - hermaphrodite
#         - often used to describe native people who were crossing or mixing genders
#     - sodomites
#         - similarly used to commit "abominable acts" in regard to male sexuality
#     - berdache
#         - an intercultural or "frontier" term used to describe people who filled a commonly accepted role in native cultures
#             - became a catch-all term for any non-binary identity
#         - believed to have been introduced by French explorers
#             - it was a common term in several European and Persian languages
#         - now understood to be derogatory
# - native gender and sexuality
#     - gender is not limited to man and woman
#     - sexuality is not limited to opposite genders defined by anatomical sex
#     - there were innumerable diverse cultures so using any single term for identities or groups is reductive and problematic
#         - specifically, hermaphrodite, sodomite, and berdache, even if they weren't used derogatorily, they would not be accurate terms
#             - these groups had and have their own conceptualization for these identities which will not fit within eurocentric terminology
#     - two spirit
#         - it is an umbrella term, but it came from within native cultures and built on existing traditions
#             - it was also in some ways required in order to replace the existing use of the umbrella term berdache
#             - the term is in english where other existing terms were in native languages
#                 - native languages have been and are being eradicated so the term is meant to have more permanence through this ongoing erasure
#                 - hence native people can use this term in lieu of cultural terms that may have been lost to them
#                     - they can identify as two spirit as a rejection of colonial terminology
#         - it is a complex term which can mean different things to different people
#             - a "western", eurocentric, or colonial lens will never be able to properly define or understand it
#             - hence outsiders should be mindful that we will not understand and should not try to assign definitive meanings to it
#                 - we must also be weary of anthropologists and other outsiders who try to define it and defer to native people
# - ongoing historical context
#     - the murder of Fred Martinez Jr. led to changes in the local high school's dress code and anti-bullying policy as well as increasing understanding of local law enforcement
#     - two-spirit/LGBTQ history cahllenged stereotypes butt also provides a path to self esteem and empowerment
#     - discussion points/thoughts on these points
#         - no change occurs unless and until suffering occurs
#         - preserving history is important to preserving the legitimacy and possibility of existence
#             - this allows people to connect with their existence in a broader context
#         - without a historical context, things will be misunderstood, missused, etc.
#         - just because something wasn't written down doesn't mean it didn't happen
#             - anthropologists, missionaries, etc. write from their own perspective and through their own lenses
#                 - e.g. the omission of stories about native women in male roles could be representative of a lack of such cases or more likely as a lack of interest in documenting them

# %% [markdown]
# ### 22Apr25 Readings
# ### Marriage Will Never Set Us Free (Willse, Spade)
# - marriage is a tool of social control
#     - it regulates sexuality and family formation
#     - marriage is rewarded
#         - other family structures are therefore punished
#     - adding a category to the charmed circle/circle of citizenship shifts things but does not significantly change the circle and does not challenge it at all
#         - it moves the line of what is considered acceptable but does not change the line itself
#         - it reinforces the legitimacy of the circle and grants it more power by virtue of bringing more people into it
#             - these people, having been granted a slight increase in legitimacy, will fight to maintain the circle
#                 - it is a pacifier which prevents necessary radical change
#     - marriage rates are used to measure "social progress" (that is, to do racism)
#     - marriage is gendered
#         - it is used to trap women and children in violent and abusive relationships
#     - marriage is about property rights
#         - land, money, and children
# - responses to common arguments
#     - you can have love without marriage
#     - <img src="images/Willse_Spade_Marriage.png" alt="Willse and Spade on marriage" width="800"/>
#     - "A real approach to changing these systems includes asking why marital status is tied to immigration and health care access, how queer and trans people are impacted by immigration imprisonment and deportation, and how homophobia and transphobia create negative health outcomes and block health care access."
#     - adding queerness to the oppressive system won't work
#         - adding diversity to police forces, the military, etc. does not change the system
#             - it just adds more people to the system and legitimizes it
#                 - "It's not just straight whites anymore. We're so advanced that we even let gay and brown people shoot brown people now!"
#     - it is naive to talk about marriage in a purely cultural context
#         - the reality is that it is a legal and social institution
#             - even if love is the only consideration for you and your spouse, you would still be affected by the legal and social implications of marriage
#                 - i.e. you don't get to have one without the other
#     - re: incremental steps toward equality
#         - the system tells us not to envision alternatives, not to challenge it
#         - "Same-sex marriage advocacy celebrates and promotes marriage, abandons all those punished by marriage systems, and tells us that while we shouldn’t get in the way of your wedding, we certainly can’t expect any solidarity from you."
# - against inclusion
#     - fights for inclusion in the military, marriage, and other institutions are not radical
#         - they do not challenge the status quo
#         - are fighting for a seat at the table, but only for themselves
#             - this is fighting **for** the status quo, just the staus quo plus them
#     - this aligns with right wing "family values" rhetoric
# ### The Affective Economy of Marriage: Or, No Spouse Left Behind (Beloso)
# - yes marriage is a tool but shaming people for wanting it is counterproductive
# - loads of people marry and can't access the "1138" benefits, rights, and protections
# - for many people, marriage is about survival and can be their sole path to these protections
# - "as Mike Ely recently observed, “you can’t judge the revolutionary potential of people by what they currently think.” But you sure can diminish the revolutionary potential of people by presenting them with a zero-sum scenario that makes them out to be losers for wanting what we’ve all been told to want, rather than eliciting from them a radical insider critique of marriage"
#
# #### my potential notes for discussion
# anti marriage:
# - hmmm
#
# pro marriage:
# - re: pacifier blocking radical change
#     - when is radical change required? If a building entrance is not ADA compliant, do we blow up the building or do we add a ramp and accessible doors?
#     - put another way, do we just blow up the government then? What is the actual process for moving forward in your understanding of the system?
#         - i.e. if we don't work within the system, how do we change it? Ok, marriage is a tool of the system so we can't use it to get queer people healthcare and housing. Can we pass a bill? Is that not also working within the oppressive system, legitimizing it's existence?
#             - tldr; yes the system is bad, yes working with the system validates it, but how is your alternative any different? or, how do we protect queer people in and after the revolution and when do we have the revolution?
# - re: the illegitimacy of marriage
#     - it being a tool of social control does not stop people from wanting it. Is it our place to tell people they can't have it because it is bad for them? In a perfect world without social pressures, would some people still choose marriage?
#     - I like bad ice cream because of its presence in a complicated and traumatic part of my life. I recognize that it isn't objectively good in flavor or texture and the attachment comes from a bad place.
#         - I don't think that means I should stop eating it or that I should be ashamed of it. I don't think that it is bad for me to eat it and derive pleasure from it (other than the health implications of eating ice cream in general).
# - re: anything about how it is ***used***, not what it ***is*** as a concept or practice
#     - marriage ***can be*** a tool for a number of evils
#         - that does not mean marriage itself is evil
#         - many things can be used as tools of oppression
#             - e.g. the internet, social media, etc.
#         - marriage could also simply not be a tool for these things if it were not used as one
#             - these very real and valid arguments are not arguments against the tool, they are arguments against the employment of the tool and the use of a relationship or relationships as a tool
#             - "if, in the process, we forget capitalism’s extraordinary capacity to morph hierarchy itself to the exigencies of economic exploitation, then we’ll just be pushing down marriage to watch another conservative affective container pop up."
#             - imagine a world where marriage has no legal implications or definitions
#                 - without normative definitions and the benefits/punishments attached, marriage would be a personal choice between two people and would be much more difficult to weaponize

# %% [markdown]
# ### 23Apr25 Class
# #### Mock Debate
# - mostly a rehashing of the above
# - at the end, no one was willing to solidly agree with either article, we all had nuanced oppinions in the middle
# #### other discussion points
# - marriage was predominantly about property "until" the 1970s
# - marriage is seen as the only truly "legitimate" relationship
#     - solidifies legal rights to children and property
#     - claiming children as dependents
# - Spade argues against trickle down approaches and instead suggests bottom up approaches
#     - i.e. instead of pushing for the the next least excluded group to be included, we should be pushing for rights for the least included

# %% [markdown]
# ### 27Apr25 Readings
# #### There Is Nothing Like a Family Discourses on Families of Choice in Poland
# - *families of choice* (2017)
#     - in the 60s and 70s, gay and lesbian individuals began to more openly form communities based on mutual support and care
#         - these communities were often formed in response to the AIDS crisis
#         - there was an increased awareness of the capacity for non-biologically familial relationships to provide the same types of support and care as "traditional" families
#             - e.g. compassion, love, and care during illness and end of life
#     - while researchers are beginning to investigate these forms of family, the work is often still affected by heteronormativity
#         - the researchers own biases and beliefs can affect the research
#         - the published results are often controversial within both public and academic discourse
#     - (as of 2017,) Poland does not recognize same sex families
#         - an attempt was made to pass various same sex partnership bills between 2003 and the writing of this article
#             - they were all largely blocked by conservatives and slow rolled by the government
# - analyzing the discourse in Poland
#     - the Polish Constitution defines marriage as “a relationship between woman and man; motherhood and
# parenthood are under the protection and care of the Polish Republic”
#         - hence any attempt to define marriage as anything other than heterosexual is framed as an attack on the constitution itself
#     - in the 2002 Polish national census, the question of "cohabitation" was added to account for non-married family entities but it excluded same sex couples
#     - "In the public opinion polls in Poland, **non-heterosexual persons are never treated as citizens** who can also create their own families. Instead, **they are almost always treated as an object, a matter of opinion.**"
#         - honestly, I found this to be a depressingly profound statement
#     - responses to the *Let Them See Us* campaign
#         - the campaign was designed to raise awareness of the existence of queer people in Poland
#         - it faced massive backlash
#         - articles at the time used the term "family" almost exclusively to mean heterosexual monogamous married couples with children
#             - homosexual relationships are framed as separate and different from families
#             - this use of language was utilized in both conservative and liberal discourse
#                 - "One may go so far as to speak of a specific alliance of the two discourses in the process of maintaining (or even naturalizing) a very normative model of the family"
#         - a split in the political language
#             - conservative discourse tends to frame queer people as an unwanted other which must be removed
#                 - Kowalkski calls this an "integral or organic homophobia"
#                 - this calls for complete elimination of queer people or at least their erasure from public life
#                 - conservative rhetoric employes stereotypes
#                     - "homosexuals promote homosexuality", "homosexuals seduce children", etc.
#                 - it also employs war-style language and "reverse rehtoric" to frame the oppressed minority group as the aggressive oppressor
#                     - many called the Let Them See Us campaign "visually aggressive", suggesting that the depiction of homosexuality itself is an attack
#                     - they frame the heterosexual majority as under threat and frame their bigotry as self defence
#             - the liberal discourse centers around assimilation of the other
#                 - the aim here is to grant some rights while maintaining overall privilege and power for normative families
#                     - e.g. calling for civil unions and other different but allegedly equal rights
#     - later discourse in 2011 allowed for a more inclusive family model

# %% [markdown]
# ### 28Apr25 Class
# - queer families of choice
#     - increased recognition of the validity of chosen family by extension validates queer identities
#     - it also allows for more of these families to form
#         - e.g. lesbians providing care for gay men during the AIDS epidemic
# - Polish marriage
#     - constitutionally defined as being between a man and a woman
#         - also includes language linking marriage to motherhood and parenthood in the same sentence
#             - this explicitly ties marriage to the idea of procreation
#         - written under pressure from the Catholic Church
#         - attempts to formalize same-sex relationships are viewed as an attack on the constitution
#             - it sounds like the Polish constitution is considered sacred and infallible in the same way that the US constitution is
#             - acts to legally regulate sexuality
#             - legally delegitimizes chosen family structures
#             - allows even civil union bills to be deemed unconstitutional as they would go against "the protection and care of the Polish Republic"
# - Family in Poland
#     - the 2002 census attempted to count family units, but it was limited to heterosexual couples
#         - in class reproduction of the questionaire results:
#             - "family" is extremely hard to define
#                 - self identification of a familial relationship seems to be the key for most or all of us
#                     - this is hard to define in a legal sense
#                 - two or more people as a couple or with children can be a family in some cases and not in others
# - heteronormativity in Poland; links to other readings and discussions
#     - existence, community, safety: it makes it harder to identify, come out, exist, etc
#     - pillars of society: marriage is defined by religion and the law and reinforced by the other pillars
#     - feels very similar to western colonialism readings re: erasure, assimilation, etc
#     - connects to readings on normativity itself
#         - only allows for one type of family and even if there was a second type it will have its own strict and singular definition
#             - i.e. even when there is a new box, it is still a box
#     - housing discrimination is legal
#     - dehumanization: normative discussion makes categorizies of people
#         - like patholigizing and clinicalizing, this takes real people and turns them into abstract concepts which need to be debated, discussed, legitimized, or delegitimized
#             - these discussions remove participants on both sides from the human reality
#                 - we tend to forget that this isn't just about "the __insert group here__ community" but about real people in **our** communities: our neighborhoods, our families, etc.
# - stereotypes of LGBTQ people
#     - further dehumanization
#     - logical shortcuts that frame the majority group as the victim

# %% [markdown]
# ### 01May25 Readings
# #### Punks, Bulldaggers, and Welfare Queens: The Radical Potential of Queer Politics? (1997)
# - racism still exists within queer communities
#     - seeking to join or replicate dominant culture and institutions is a recipe for recreating the same hierarchies and oppressions
# - Cohen argues that queer politics should be radical and challenge the status quo but has (at the time of writing) not done so
#     - "instead of destabilizing the assumed categories and binaries of sexual identity, queer politics has served to reinforce simple dichotomies between heterosexual and everything ‘queer’"
#     - "Thus, if there is any truly radical potential to be found in the idea of queerness and the practice of queer politics, it would seem to be located in its ability to create a space in opposition to dominant norms, a space where transformational political work can begin."
# - "queer" began to be regularly used in the 1990s
#     - it was used to describe a wide range of identities and practices
#         - it was also used to describe a rejection of the normative ideals for gender and sexuality
# - Cohen criticizes people who use only one aspect of their identity to define themselves and their politics
#     - this is in a way a rejection of intersectionality and it undermines the radical potential of queer politics
#     - "Proceeding from the starting point of a system-based left analysis, strategies built upon the possibility of incorporation and assimilation are exposed as simply expanding and making accessible the status quo for more privileged members of marginal groups"
#     - transformation $\gt$ assimilation
# - a "left[ist] framework"
#     - a framework which "makes central the interdependency among multiple systems of domination"
#     - "By leftist we mean people who understand the struggle for lesbian and gay liberation to be integrally tied to struggles against class oppression, racism, and sexism."
#     - leftist politics is itself an umbrella term for a collection of political ideologies
# - "... queerness, as it is currently constructed, offers no viable political alternative since it invites us to put forth a political agenda that makes invisible the prominence of race, class, and to varying degrees gender in determining the life chances of those on both sides of the hetero/queer divide."
# - black lesbian activist and writer Barbara Smith argues that modern (at the time of writing) queer politics seek to operate in an ideological and historical vacuum
#     - i.e. they focus solely on issues stemming from the queer identity and ignore the historical and social context

# %% [markdown]
# ### 02May25 Class
# - queer politics (at least in the 90s) recognizes and encourages fluidity and movement
#     - it failed to challenge heteronormativity
#     - it was largely a response to the preceding era of identity politics
#         - identity politics are often reductive and do not account for the complexity of individual identities
#     - it framed queer identities as oppositional to heterosexual identities
#         - heterosexuality is not the enemy, heteronormativity is
#             - i.e. it's ok to be straight, it's not ok to tell people they have to be straight
#     - Cohen argues that the term queer does not only refer to sexual identity
#         - she suggests that heterosexual people can be queer
#             - e.g. members of the kink community or poly communities
# - discussion of the quote on queers operating out of political individualism
#     - an individualist ideology allows people to live in a vacuum in the same problematic way non-queer people do
#         - we do not live in a vacuum
#             - it allows people to ignore the social and political context of their lives
#             - it allows people to ignore the history of oppression and violence against queer people
#                 - this is a form of erasure
#             - it also allows people to ignore the fact that they are not alone in their struggles
#                 - this isolates them and in turn isolates others from them
#         - this ideology privileges those who can "pass" as the dominant group
#             - many of the people with this privilege are never forced to rely on the community for support
#                 - this distances them from the community and the struggles of the community
#                 - this makes using the identity more hollow
#                     - it is used as a label, not an interpersonal relationship and community based experience
#             - allows them to fight the symptoms, not the illness
#         - allows people to be "fair weather" members of the queer or other communities
#             - identifying as queer when it is convenient but not when it is not
# - discussion of the quote on intersectional analysis of power and concrete coalition building
#     - we have to put up or shut up to leverage our privilege
#         - if you have the privilege, you should be leveraging it to help people and to reach out
#     - we will not be able to fix the world alone and we will not bring new people in while focusing on a single issue only
#         - i.e. instead of a bunch of small groups pushing for their individual issues, we need to be a united front pushing in the same direction
#     - an individualistic approach to oppression is not an effective way to recognize and fight the systemic root causes of oppression
# - stigmatized heterosexuality
#     - examples:
#         - breadwinning women
#             - according to the definition of queer politics which is called out in the article as inadequate, these are not queer identities
#             - despite not being strictly gay/lesbian/queer, criticizms of the straight couple will be those leveled at gay and lesbian couples
#                 - e.g. to heteronormative bigots, the man will be seen as gay and the woman will be seen as a lesbian
#                     - calling a straight man "gay" as a pejorative is not wrong because he is straight, it is wrong because it is a pejorative
#                         - i.e. the issue of heteronormativity affects everyone and is wrong for everyone regardless of their identity and this is a point of potential solidarity
#         - couples that cannot conceive
#             - they have common ground with international couples or couples with foster children
#         - racialized teen/single mothers
#             - they have common ground with black queer people who are labeled as "deviant"
#         - lower class housing issues
#             - they have common ground with issues around abortion access
#             -

# %% [markdown]
# ### 04May25 Readings
# #### Coalition Politics: Turning the Century
# - coalition work is about survival not comfort
# - do not confuse a coalition with a "home" or safe space
#     - coalitions happen in the streets and in the world
# - nationalism is a stage but it can become a trap if you stay there
#     - A homogeneous room can build strength, yet it turns reactionary and “totally inadequate for surviving in the world with many peoples” once you refuse to open the door
# - technology has ended some forms of isolation
#     - there is no place which is solely your own
# - coalitions require work
#     - you have to be willing to work, but also mindful of when to step away
#     - don't burn out or die for the cause unintentionally
# - "our" must include everyone whos existence is tied to yours
# - single issue politics are dead
#     - there is no single issue and we can't only deal with one thing at a time
# - coalitions expose differences and cause friction - this is good and expected
#     - you can't suppress differences, you have to work through the discomfort
# - coalition building requires a long term view
#     - you have to see the world in terms of decades or more, not days or weeks
# - respect history
#     - every movement builds on past movements, particularly the struggle for black freedom

# %% [markdown]
# ### 05May25 Class
# - the end of isolation
#     - historical context for the 1980s
#         - different identities start to be recognized more prevalently
#             - this leads to both community and persecution
#         - the AIDS crisis
#         - civil rights movement continues
#         - Reagan is president
#     - there are far fewer single issue social groups
#     - Reagon (the author of the article)
#         - born into the height of the civil rights movement
#         - musician and activist
#         - this article was a speech given at a women's music festival
#             - by the 80s there is a push for women's music festivals
#                 - the goal was for women to be able to create, perform, and experience music safely
#                 - could be highly transphobic or otherwise exclusionary
#                     - sounds like this was mostly the Michigan Womyn's Music Festival
#     - Reagon critiques the formation of these spaces as a solution to the problems of the world
#         - simply excluding people is not going to solve the problems of the world, it only hides from them
#         - not forming coalitions is like sitting in your home and barring the doors
#             - it also lets the bad people paint your door red
#     - example of a coalition
#         - in the push for domestic partnerships: LGB groups and AARP and some immigrants rights groups
#             - there was common ground in seeking to gain rights without marriage
# -  Dr. Batza considers today far more fractured than the 1980s
#     - we have to do the hard work and be uncomfortable
#     - we also have to have our individual "tents" or "homes" to go back to and recharge
