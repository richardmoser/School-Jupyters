# %% [raw]
# \usepackage{ulem}#%%

# %% [markdown]
# # **Unit 1, Section 1: Terms, Places, and Context**

# %% [markdown]
# # Transcribed Paper Notes:

# %% [markdown]
# #### **Note:**
# - these are the notes I took prior to becoming a note taker and are not as detailed as my later notes
# - they may include:
#     - highly simplified summaries of the thesis
#     - convoluted metaphors which may not be helpful to people who are not me
#     - questions/talking points I intended to bring up in class
#         - (the last WGSS course I took was significantly more discussion driven)
# - I have revised some of the more egregious errors I found but did not go back into most of the readings to re-summarize them.
# - **if you have any questions, need clarification, or would like me to expand on any of these notes, please let me know**
#     - this includes going back into the readings to re-summarize them if that would be helpful
# ### 24Jan25 Readings and Class
# - Heterosexual Privilege Checklist
#     - the world was built almost exclusively **for** straight dudes, to **fit** straight dudes' identity, to **enforce and maintain** straight dudes' identity, and to **punish** those who don't fit that identity
# - Cisgender Privilege Checklist
#     - as above
#     - describes a long list of things which cis people don't have to think about or even know exist as concepts
#     - a lot of "well of course I can do..." and only then realizing that others cannot
#     - e.g. :
#         ```
#         8) Strangers do not ask me what my "real name" [birth name] is and then assume that they have a right to call me by that name.
#         9) People do not disrespect me by using incorrect pronouns even after they've been corrected.
#         10) I do not have to worry that someone wants to be my friend or have sex with me in order to prove his or her "hipness" or “good” politics.
#         11) I do not have to worry about whether I will be able to find a safe and accessible bathroom or locker room to use.
#         ```
# ### 27Jan25 Readings
# #### The Word Cisgender
# - note: in class I thought that the instructor indicated that this text argued that the term "cisgender" reinforced norms and helped to other trans and gender nonconforming people
#     - I did not get this on first reading and have revisited the article, again finding that it argues the opposite
#     - I may have misunderstood the instructor but I wanted to be upfront about this discrepancy
# - my weird metaphor and analysis for understanding the reading (not from the reading)
#     - yin legitimizes Yang
#         - we don't have a term for people with red blood or people who breathe air
#             - as far as I know, people with colors of blood or other prefered respiratory systems don't exist
#             - more importantly, we don't conceive of their existence nor consider our own existence in these terms
#                 - to be person is to be assumed to have red blood and breathe air, there's no need to specify
#                 - that is the default and we don't even think of it as default because that would imply that there are other options
#         - creating and using a term for what is considered the default implies the existence of alternatives
#         - after all, there would be no word for yin if yang were not real and valid in its own right
#             - possibly a terrible metaphore, but it's the one I've got
# - from the reading
#     - "'Cisgender' suggests a commonality among transgender and non-transgender people...It tells us that we all experience some kind of relationship between our bodies and our selves, whatever that relationship may be."
#         - -- Paula Blank
#         - important corollaries to this recognition that cis people also have a relationship between their bodies and selves:
#             - being "gender conforming" is it's own condition, not a lack of a condition
#                 - it is thus in need of being accounted for
#             - **what is "normal" is having a relationship to gender, not having a specific relationship to it**
#                 - from this context, gender nonconforming people are not people having an unknowable or alien experience, but people having a different version of a common experience that all people have
# #### Dismantling Cis Privilege
# - this piece discusses "gendering", the process of evaluating the gender identity of new people we meet
#     - especially for cis people, this is largely subconscious and automatic
#         - because cis people are rarely wrong, or at least rarely told, and rarely misgendered so they don't have to think about it
#     - the "cissexual assumption": the assumption that everyone is cisgender until proven otherwise
#         - i.e. "my experience must be universal, everyone is like me"
# - the author compares the "birthright" gender argument to other birthright arguments such as caste systems
# - trans facsimilation
#     - if person A didn't know that person B was trans, they wouldn't think anything of it
#     - if person A finds out, they often begin to think of all the ways that person B is different from their expectation of a "rea" member of their gender
#         - this is often a subconscious process
#     - everything is just normal differences between people until there's a reason to expect them to be different
#         - i.e. suddenly you have a conclusion (they are trans) looking for evidence
#             - prior to being made aware of this "conclusion", person A had made their own conclusions about person B based on the same evidence
#                 - why does the new conclusion invalidate the old one?
# - **most genetic male/female people have never been genetically tested to confirm their genetic sex**
#     - so honestly, most people don't know their own genetic sex
# - notions of "biological" sex are similarly flawed
#     - what does "biological sex" mean?
#     - if it's about your parts, what about people who are sterile? Are post-menopausal women suddenly without gender?
# - third gendering
#     - use of language like FTM, MTF, trans man, etc can be othering
#     - e.g. FTM or trans man differentiates them from "real" men and creates a separate category
# - gendering and passing
#     - gendering is an active process by society
#     - passing is a passive process by the individual
#         - the language implies some kind of deception or trickery

# %% [markdown]
# ### 25Jan25 Readings
# #### Heteronormativity
# - heteronormativity is the assumption that everyone is heterosexual
# - establishes "rules" for what is "normal" and "correct" for people to be and do
# - involves, enables, and enforces gender roles and stereotypes
# - similarly enables and enforces white supremacy
#     - if the state defines marriage, it can exclude people of color, polyamorous, queer, etc. people
# #### Homonormativity
# - as above but within the queer community
# - similarly establishes social rules
#     - adds a checkbox or two to the existing system but doesn't actually change the system much
# - allows specific types of representation, usually white, cis, and monogamous
#     - e.g. Niel Patrick Harris, Anderson Cooper, Ellen Degeneres
# - seen in queer organizations that exclude or ignore some groups outside the norm
#     - e.g. TERFs, Human Rights Campaign
# - homonationalism ties homonormativity to nationalism
#     - e.g. Israel using it's supposed "gay utopia" status as a tool to perpetuate Islamaphobia and justify violence
# #### Bisexuality

# %% [markdown]
# # Organized (hopefully) Notes:

# %% [markdown]
# ### Readings 31Jan25
# #### Settler Colonialism Primer (2014)
# - Colonialism: occupies and usurps land, resources, and labor from indigenous peoples
# - types of colonialism
#     - exploitation colonialism: a small number of colonists exploit resources and indigenous labor for export to the colonizing country
#         - the colonists are not interested in the land itself, only the resources
#     - **settler colonialism**: focuses on land and the elimination of indigenous peoples to make way for settlers
#         - the colonists are interested in the land itself
#     - plantation colonialism: a mix of exploitation and settler colonialism, where the colonists are primarily interested in the land and the resources it can produce
# - indigenous peoples are erased via genocide, assimilation, or interbreeding
# - a settler is anyone who is not indigenous to the land in a settler colonial context
#     - e.g. any non-indigenous person in the US
#     - intersects with other identities such as race, class, etc.
#         - not all settlers are equal or chose to be settlers
# - primitive accumulation: the process of acquiring land and resources from a group of people who are not capitalists.
#     - i.e. stealing land to create a landless working class
#     - without land to farm or resources to sell, people are forced to work for wages to survive
#     - "entry point into capitalism"
# - racial formation: the process of creating racial categories and attributing characteristics to them in order to justify the exploitation of certain groups
#     - used to maximize exploitation and minimize benefits to the exploited groups
#         - you must be a minimum percent genetically indigenous to be be deemed a tribal member
#         - a maximum of "one drop" (any) of black blood made you black per the "one drop rule"
#     - "whiteness" must then be defined in opposition to these racial categories
#         - whiteness is defined as the absence of the characteristics attributed to the exploited groups
#             - there is no definition of "white", only what is not white
# - assigning innocence to settlers
#     - settler nativism
#         - settlers find or invent an indigenous ancestor to absolve themselves of any possible blame or guilt
#         - even if true, it is likely that your indigenous great-grandmother did not have a choice in marrying a settler
#     - fantasizing adoption
#         - settlers adopt practices and knowledge of indigenous peoples or cite narratives of the dwindling indigenous people handing over the land to settlers for safe-keeping
#     - colonial equivocation
#         - settlers conflate colonialism with other forms of oppression
#             - "we are all colonized" does not mean "none of us are settlers"
#     - conscientization/mental decolonialization
#         - yes we must free our minds, but we must also free the land
#         - consciousness raising is a comfortable way of avoiding the hard work of decolonization

# %% [markdown]
# #### Decolonizing Feminism: Challenging Connections between Settler Colonialism and Heteropatriarchy (2013)
# - indigenous communities are often less interested in equality and civil rights from the colonial state and more interested in independence and sovereignty from the colonial state
#     - the colonial state is not a neutral arbiter of social justice, but a colonizer itself
# - First Challenge: problematize and theorize the intersections of settler colonialism, heteropatriarchy, and heteropaternalism - Second Challenge: refuse the erasure of Indigenous women within gender and women’s studies and reconsider the implications of the end game of (only) inclusion
# - Third Challenge: actively seek alliances in which differences are respected and issues of land and tribal belonging are not erased in order to create solidarity, but rather, relationships to settler colonialism are acknowledged as issues that are critical to social justice and political work that must be addressed
# - Fourth Challenge: to recognize the persistence of Indigenous concepts and epistemologies, or ways of knowing.
#     - recognizing the persistence of Indigenous concepts and epistemologies does not mean blindly copying or performing them oneself, nor does such recognition require excavating “authentic” Indigenous traditions out of a distant past; instead, feminists must recognize Indigenous peoples as the authors of important theories about the world we all live in
#     - land is not just property, it is a relationship and a source of knowledge
#     - sovereignty is not only derived by the colonial state; tribal lands, councils, and other institutions are benefits granted by and powers derived from the dominant settler state and thus are not truly sovereign. They come with problematic strings attached.
# - Fifth Challenge: to question how the discursive and material practices of gender and women’s studies and the academy writ large may participate in the dispossession of Indigenous peoples’ lands, livelihoods, and futures, and to then divest from these practices

# %% [markdown]
# ### 31Jan25 Class
# - Question: What tribal land does KU sit on?
#     - per the land acknowledgement, it sits on land that was forcibly ceded by the Kaw, Osage, and Shawnee peoples among others
# - if this material is interesting, there is a Native Feminisms course in the department
# - our education system tends to teach colonialism as a thing of the past
#     - something that happened, not something that is happening
#     - there is no such thing as true post-colonialism
#         - it is a massive amount of structural harm in addition to generational trauma and multiple genocides
#         - e.g. KU discovering that they have a collection of indigenous remains in recent years and resisting returning them to their tribes
# - primitive accumulation
#     - settlers set able to norms because they've stolen the resources, land, and power
#         - gender binaries are constructed and enforced by settlers to maintain power and control
#         - racial formation
# - racial formation
#     - creates a racial hierarchy which can also be used to justify who is granted or "deserving of" rights and who is not
#     - arbitrarily defines a "white" race and **establishes it as the norm**
#         - norm is assumed to mean "correct" and "right"
# - decolonization
#     - literal unsettling
#     - complete reparation of land
#     - for the settler this means facing that
#         - there is not necessarily a place for you in the new society
#         - settler destiny and narratives no longer take center stage
#     - decolonization is accountable to indigenous sovereignty and futurity
#         - not to settlers and settler futurity
#     - self-accepting colonizer
#         - a settler who accepts that they are a colonizer
#             - either knowingly or unknowingly
#     - self-rejecting colonizer
#         - a settler who will fight for a world which may not include them
#         - you can't claim to be an ally, it may be possible to be designated as such by the oppressed group
#     - approaches discussed in groups in class
#         - systemic changes such as K-12 education
#         - reparations
#         - returning land
#         - electing/bringing indigenous people into existing systems of power
#         - center indigenous voices and narratives in all of these processes
#             - many or all of these are highly complex and difficult to achieve
#             - it is vital that we leverage privilege to elevate these voices to power **but then shut up and let them speak and make policy**
# - five challenges to decolonizing feminism
#     - native feminisms must be not only added to curriculum as a discrete topic, but also integrated into all other topics
#     - the roots of many or most issues along gender lines are in settler colonialism
#         - i.e. indigenous cultures didn't have these issues until settlers arrived and imposed their norms
#     - allyship cannot be a trend or a part time job in the way some political movements are
#         - it must be a full time commitment to conscious action and policy
#         - it is on the settlers to do the work, not the oppressed
#             - it is not their job to teach you how to be an ally
#     - recognize indigenous knowledge and epistemologies without appropriating them
#         - this knowledge and these concepts are current and ongoing, not historical
#     - divest from practices that harm indigenous peoples
#         - this is difficult work
#         - reform curricula and practices to be more inclusive and less harmful
# - cut for time: TEDxSFU talk on Canadian indigenous issues

# %% [markdown]
# Readings 03Feb25
#
# ### Demarginalizing the Intersection of Race and Sex (1989)
# - discrimination does not always occur along a single axis
#     - i.e. people may be discriminated against for multiple identities at once
#     - the "women's experience" and "black experience" are not monolithic and should not be treated as such
#         - doing so excludes people whose identities intersect with these groups rather than fall discretely into them
# - legal examples
#     - courts have ruled that black women could not sue for discrimination as black women, only as black or as women
#     - courts have alternatively ruled that black women could not sue for discrimination as black because they are not representative of black men
# - antidiscrimination law is written assuming privilege "but for" one characteristic
#     - e.g. gender discrimination laws are written for white women
#         - privileged but for their womanhood
# - anti rape legislation was written with the assumption of white women's chastity
#     - courts in some states were literally told black women could not be assumed chaste

# %% [markdown]
# # 03Feb25 Class
# - video
#     - Kimberle Crenshaw TED talk, TEDWomen San Francisco, October 2016
#     - TW: (in the video) discussion of violence against black bodies
#     - names exercise
#         - varied audiences are consistently more aware of police violence against african american men than women
#         - we struggle to process information that does not fit within our preconceived notions
#             - our "frames" of understanding as she calls them
#         - this allows us to ignore or dismiss information that does not fit within our frames
#             - intersectional issues and cases slip through the cracks
#     - DeGraffenreid v General Motors
#         - cited in the reading
#         - sued GM for not employing black women
#         - court ruled that DeGraffenreid could not sue because GM hired black (men) employees and (white) women
#     - intersectionality
#         - the roads are the way the workforce is structured around gender and race
#         - the law is an ambulance that arrives at an intersection after an accident has occurred
#             - refuses to treat the injured because they do not exist on a single road
#     - police violence against african american women
#         - under-reported by media
#         - under-remembered by the public
#     - **if we can't see a problem, we can't fix it**
# - intersectionality
#     - term coined by Kimberle Crenshaw in 1989
#     - the concept existed long before the term was coined
# - waves of feminism and black feminist theorists
#     - 1st wave (1800s-1920s)
#         - abolition, women's suffrage
#         - Sojourner Truth, Anna Julia Cooper, Ida B. Wells
#     - 2nd wave (1960s-1970s)
#         - civil rights
#         - Angela Davis, Patricia Hill Collins, Combahhee River Collective, Barbara Christian, Audre Lorde, Shirley Chisholm
#     - 3rd wave (1990s-2000s)
#         - critiquing the second wave
#         - Rebecca Walker, bell hooks, Toni Morrison, Barbara Ransby, Loretta Ross, Kimberle Crenshaw
#     - 4th wave (2010s-present)
#         - \#metoo, black lives matter
#         - Brittany Cooper, Roxane Gay, Jennifer Nash, Katherine McKittrick, Moya Bailey, Tarana Burke

# %% [markdown]
# # 04Feb25 Readings
# ### When Everyone Can Be 'Queer,' Is Anyone? (2016)
# - if queer, a term that once meant non-normative sexuality, has become (part of) the norm, what does it mean to be queer?
#     - "when everyone can be queer, is anyone?"
#     - "There is now a right way to be queer... to invert the norms of straight society" - David Halperin
# ### Queer Resistance: Reclamation & Resilience (2018)
# - identifying as queer can be seen as an active decision, not a passive statement of circumstance
# - queerness can be a defensive or even offensive response to the heteronormativity and trauma
#     - that does not make it any less valid, only more complex
# ### Time to lay ‘Born This Way’ to Rest (2015)
# - sexual fluidity: the idea that sexuality is not fixed and can change over time
# - the "born this way" narrative is limiting and outdated
#     - originally a response to 1960s/70s era anti gay sentiment
#     - meant to signal a lack of choice in sexuality
# - heteronormativity pushes people in the middle of the sexuality spectrum to choose a side
#     - "Probably there's a core part of the population that is... like, "I am gay and I'm going to find some way to be gay". But the most common form of same-sex attraction is... a bisexual form. If you are bisexually attracted you may think, "Wow, the world is going to hate me if I end up with someone of the same sex, my life is going to be a lot easier if I end up with someone of the opposite sex." So you end up focusing on that."
# - ultimately, we have to recognize that sexuality is complex and it's roots are equally complex
#     - it is likely driven by a mix of genetics, environment, experience, personal choice, and much more
#         - no single component and no combination of components can fully explain sexuality
#         - no component or components can invalidate a sexuality
#             - a sexuality is valid because it is
#     - "It's unscientific, it's unnecessary and it's unjust. It doesn't matter how we got to be this way. As a scientist, I think it's one of the most fascinating questions out there and one that I will continue to investigate. As a lesbian and a progressive, I think it's totally irrelevant and just politics."
