# %% [markdown]
# # **Unit 2, Section 1: Science and Health**

# %% [markdown]
# # 16Feb25 Readings
# ### HIV Is Not for Me
# - HIV/AIDS in WSW communities of sub-Saharan Africa are not well understood
# - research and discussions of this topic are complicated by social stigmatization of WSW individuals from within their own communities
#     - WSW is often seen as not at risk for HIV/AIDS and therefore any infection is regarded as a result of promiscuity outside of "real" lesbianism
#     - in reality, WSW individuals are at risk for HIV/AIDS and a lack of awareness increases the risk of infection
#     - over 50% of participants had not talked to a healthcare workerd about sexual health
# - increased awareness and education is needed to combat the spread of HIV/AIDS in WSW communities
#     - social stigmas must be addressed to allow for open discussion and education
#     - education must be tailored to the specific needs of WSW individuals
#     - the internet is a valuable resource for providing information and support and some participants had used it to find information
# - the African Charter on Human and People's Rights on the Rights of Women
#     - ratified by most African countries
#         - enforcement varies by country as does equitable access to healthcare
#     - provides a framework for addressing women's rights and health issues including HIV/AIDS
#     - does not specifically address sexual orientation
#         - still, WSW clearly qualify as "women" and are therefore protected under the charter as women
#         - WSW sex may not be considered sex within the legal definition of the charter
# ### From Health Crisis to Rights Advocacy
# - much has been written about the relationship between HIV/AIDS and LGBTQ activism in the United States
# - this paper looks into similar movements in China and Singapore
#     - despite authoritarian governments, HIV/AIDS created an opportunity for LGBTQ activism
#     - governments were eventually forced to address the epidemic
#     - some organizations were able to use the epidemic to push for LGBTQ rights while others attempted to distance themselves from it to avoid further stigmatization
# - in China, funding for HIV/AIDS research and prevention came from both international and domestic sources but was allocated by the government in either case
# - in Singapore, the government controlled the funding and engagement with activists to limit their ability to challenge the political status quo
#     - same-sex contact between men is illegal in Singapore
#     - in the first decade, NGOs were forced to be funded domestically by local private supporters
#         - Singapore is considered "developed" and therefore largely ignored by international funding sources
#         - the government did not provide significant funding for HIV/AIDS research and prevention
#     - in the 1990s, the government provided increased funding but used it as a means to control and limit the activities of NGOs
#         - those who accepted funding were required to follow government guidelines
#         - they could not advocate for other LGBTQ rights
# - main strategies employed by groups
#     - partner with the state, avoid LGBTQ advocacy
#         - registered
#         - focused on HIV/AIDS prevention
#         - distanced themselves from LGBTQ activism
#     - partner with the state, attempt to advocate for LGBTQ rights where possible
#         - registered
#         - focused on HIV/AIDS prevention
#         - attempted to advocate for LGBTQ rights in non-confrontational ways
#     - avoid the state, advocate for LGBTQ rights
#         - unregistered
#         - focused on adancing LGBTQ rights
#     - avoid the state challenge the state
#         - unregistered
#         - campaigned against anti-LGBTQ laws
# - international agencies and donors attempted to support activism in Singapore but were limited by the government's control over funding

# %% [markdown]
# ### 17Feb25 Class
# - snow day makeup on Asexuality
#     - asexuality: the orientation in which individuals do not experience sexual attraction
#     - the normalization of sexual attraction
#         - key concepts
#             - heteronormativity
#                 - we assume not only straightness, but also that everyone is sexual
#             - "compulsory sexuality"
#                 - the idea that everyone should be sexual
#                 - coined by Adrienne Rich
#                 - negative impacts
#                     - pathologization
#                         - lack of interest in sex has historically been pathologized as a medical condition
#                         - legitimizes medical intervention, discrimination, etc.
#                     - isolation and invisibility
#                         - asexual individuals are often isolated and invisible in society
#                     - unwanted sex and relationship conflict
#                         - asexual individuals frequently feel pressured into sexual activity
#                         - this can make maintaining relationships difficult
#                         - in a nuanced and complex way, one may consent to sex without desiring it
#                             - analogy: I don't want to help someone clean their garage, but if I love them I will because it is important to them
#                     - denial of epistemic authority
#                         - asexual individuals are often told that they aren't really asexual, haven't met the right person, are late bloomers, etc.
#                         - denies that the asexual individual knows themselves
#             - sex positivity
#                 - moving away from shame and stigma
#                 - legitimizing being a sexual being and sex for the sake of pleasure
#                 - can still act as a normative force analogous to homonormativity
#                     - can erase asexuality if it treats sexuality as compulsory
#                     - can define "normal" sexuality
#                 - came out of the "sex wars" of the 1980s and 1990s
#                     - feminists debated whether things like porn and kink were liberating or oppressive
#                 - sex positivity an evolving concept
#                     - originally centered around straight, white, cis, monogomous, etc. identities
#                     - now it is (generally) more inclusive
#                         - it is important to ensure that it is inclusive of asexuality and other identities
#             - non-normative forms of sexual pleasure
#                 - kink, an absence of sexual pleasure, etc
#         - challenging norms
#             - language of difference and capacity
#             - desexualizing the world
#                 - asexuality may not play a large role in one's life
#                 - asexuals may not see the world through a sexual lens
#                     - i.e. (if I understood it correctly) they think in terms of sexuality so infrequently that it is not a significant part of their identity
#             - new relationships
#                 - new types of relationships that are not based on sexual attraction
#                 - types of attraction
#                     - sexual
#                     - romantic
#                     - emotional
#                     - aesthetic
#                     - intellectual (sapiosexual)
#                         - attraction to intelligence, similar nerdy interests, neurodiversity, etc.
#                     - and many more
#                     - society teaches that all of these types of attraction are contained within sexual attraction
#                     - this is not the case
#                     - e.g. one may be (probably is?) strongly emotionally attracted to their best friend but not sexually attracted to them
#                     - as a result one may be heterosexual but biromantic or many other combinations
#             - orientation and/or identity
#             - community building and visibility
#                 - forming communities and providing visibility can help to combat isolation and invisibility and challenge norms
# - HIV/AIDS in the international context
#     - Africa
#         - reminder: it is a continent of over 50 countries and many different cultures
#         - key points
#             - non-discrimination has been framed in terms of a right to privacy
#                 - the US also frames it this way for a long time
#                 - frames it as something which may or should be hidden
#             - sexual orientation and gender presentation affect access to and quality of healthcare as well as access to information
#             - legitimization of some sexual orientations and sex acts over others
#                 - e.g. in some countries, only penis-in-vagina based sexual acts "count" legally
#         - WSW reading
#             - myth of lesbian immunity
#             - sexual identity predicts sexual behavior
#                 - i.e. an identified lesbian cannot conceivably have sex with a man
#             - fear of marginalization in the WSW community
#                 - adds another layer of marginalization on top of being a woman and queer
#         - China & Singapore reading
#             - **HIV/AIDS and activism are intrinsically linked to**
#                 - laws & regulations
#                 - political norms
#                 - the allocation of funding and responses to HIV/AIDS
#                 - collective action
#             - worsened political conditions provide opportunities for collective action
#                 - see the four main strategies of cooperation or avoidance with the government above
#                     - organizations must decide how much they trust the government and whether they believe there is a net positive impact to cooperation or resistance

# %% [markdown]
# ### 23Feb25 Readings
# #### Capitalism and Gay Identity (John D'Emilio)
# - the 1970s saw a shift toward social acceptance of homosexuality and an easing of legal restrictions in the US
# - the 1980s saw a resurgence of right wing politics
# - queer history has often been discussed as if it began in the mid 20th century
#     - because it was not well documented or at least not well understood before then, D'emilio argues that a mythic history was created in its place
#     - the mythic history (probably inadvertently) suggests that the oppression of queer people is timeless and unchanging and that queer people have always existed as a distinct group
# - challenging the myth
#     - capitalism converted economically independent family units into dependent wage earners and consumers
#         - this created a new form of family life
#         - a family was still internally interdependent but not economically independent from the rest of society
#             - in the 1800s, the wife still cooked bread but she bought the flour and the man worked for the money to buy the flour
#             - i.e. the family was no longer self-sufficient and the woman was still dependent
#     - the new economics changed the definition of heterosexual norms
#         - prior to this change, sex was meant for procreation and birth rates were high
#             - multiple children were needed to work the farm or business and overcome high infant mortality rates
#             - the societal definition of morally acceptable sexuality was built around procreation
#                 - i.e. it was not that heterosexuality was celebrated, rather it was that *any* form of sex out of wedlock was condemned
#         - after the change, birth rates dropped and the purpose of sex changed
#             - the economic changes allowed queer people to explore their sexualities in more material ways and form communities
#             - notions of sexual identity began to form
#                 - i.e. homosexuality became a distinct identity rather than a behavior
#         - WWII threw people into gender segregated environments
#             - it allowed queer people to find each other
#             - it allowed people to realize their attractions and identities
#     - still, broader capitalist society resisted and oppressed queer people
#         - in some ways the enforcement of the oppression has merely shifted from the state to extralegal violence
#             - (or maybe the state is about to pick up the torch again - not that the mob is dropping it)
#         - capitalism acts to undermine the nuclear family
#             - it removed the economic independence of the family unit
#                 - i.e. now a person or family has to work for someone else in order to survive
#             - eventually it removed the economic interdependence within the family unit
#                 - i.e. now a person can work for the money to buy pre-baked bread on their own and skip the spouse, the farm, the kids, and the flour altogether
#             - it has socialized child rearing and made it a public responsibility
#         - despite this, it still mandates the nuclear family as the ideal
#             - *a man and woman must marry and have children*
#             - *children are the responsibility of the parents*
#         - as capitalism knocks the foundation out from under the nuclear family, it scapegoats queer people for the instability of the system

# %% [markdown]
# #### Scandalous Acts (Don Kulick & Charles H. Klein)
# - Brazilian travesti prostitutes use "scandals" to extort more money from clients
#     - a scandal is a loud argument effectively acting as a threat to make a public scene and reveal the purportedly heterosexual client's proclivities
#     - an overwhelming majority of clients request to be penetrated by the travestis while maintaining that they are heterosexual
# - the travestis are effectively using the opposite of a "pride" strategy to level the playing field in a similarly shame based society
#     - a pride strategy would be to say "yes, I am homosexual and that is fine"
#     - a scandal strategy would be to say "look at how homosexual you are and how wrong that is"
#         - specifically it would be said loudly such that others could hear, with the intent of causing embarrassment and shame to the client into paying more
#         - this redistributes power and money to the oppressed group
# - travesti protests similarly do not focus on "pride"
#     - lingerie and outrageous clothing and makeup are worn
#     - signs carry modest slogans such as "Travestis are human beings" or "Travestis are citizens"
#         - the scandal here is in that if the travesti is a human being and a citizen, then the society, like the client, is not acting humanely or like a good citizen
#     - at their most different and most shameless, travestis assert that they are most like everyone else
#         - **this strategy refuses to accept differentiation and declare sameness**
# - travesti, per this article at least, do not view themselves as women or transgender
#     - still, they use estrogen and silicone to feminize themselves and use the pronoun "she"
#
# - Brazilian travisti are found in all cities of any size, appear on telivision, in magzines and parades, and sell out the copies of Playboy that they appear on
#     - these travesti tend to be exceptions, not the rule
#     - they are victims of brutality and discrimination
# - as sex workers, travestis were especially hard hit by the AIDS epidemic
# - Brazilian AIDs discourse from both travesti and other gay rights groups has centered around reterritorializing shame

# %% [markdown]
# ### 24Feb25 Class
# - Capitalism and Gay Identity (John D'Emilio)
#     - D'Emilio was Dr. Batza's thesis advisor
#     - continues with the theme of exploring sexuality through history
#         - sex acts vs sexuality/sexual identity
#     - pre-1800s: largely agrarian society
#         - family groups exist as self-sufficient economic units
#             - they are economically independent from the rest of society
#             - the family is internally interdependent
#                 - this form of self-sufficiency necessitates children
#                 - forces procreative heterosexual coupling
#     - 1800s: industrialization
#         - urbanization: the move towards cities
#             - less ownership of both land and labor in the working class
#                 - wealthy capitalists own the means of production and the working class must sell their labor to survive
#             - wage labor begins to replace the self-sufficient family unit with a new model
#                 - fewer children: having many children is no longer necessary for survival
#                     - more children are more mouths to feed and not more hands to work
#                 - men leave the homestead: men are the ones selling their labor while women largely remain in the home
#         - the gay identity begins to form in the middle of this century
#             - the breakdown of forced heterosexual coupling allows for exploration and for behaviors to become identities
#                 - i.e. one can now economically survive ***and*** go home to someone they are attracted to
#     - 1900s: capitalist society
#         - urbanization and birth rate decline continues
#         - suburbanization
#         - women begin to work outside the home
#             - this further breaks down the interdependence of the procreative heterosexual family model
#             - a woman may not need a man to survive and vice versa
#             - especially during WWII
#         - the nuclear family becomes the ideal
#             - a heterosexual couple with children
#                 - shift away from multigenerational family homes, extended family, etc.
#             - despite the fact that it is less economically incentivized/required than perhaps ever before
#         - bachelorhood and spinsterhood
#             - spinster originally meant a woman who could spin yarn so fast that she could support herself
#             - an individual could now survive economically entirely without a spouse
#                 - dependence on parents, children, or a spouse is greatly lessened for many
#         - WWII
#             - segregation of the sexes as men go to war and women join the workforce
#                 - factory barracks house women together
#                 - the military housed men together
#                 - spurred civil rights movements
#         - the gay identity really takes shape in this period

# %% [markdown]
# ### 25Feb25 Readings
# #### Capitalism, LGBT Activism, and Queer Autonomy in Thailand
# - for all the harm it has done, capitalism has helped to globalize queer identities and activism
# - despite this, it has also allowed regional and national identities to flourish
# - In Thailand, the captialist system is eager to provide services and products to the gay and transgender community but it is often at an exploitative cost
#     - lesbians are still women and thus still face discrimination and cultural restriction
#     - gay men are expected to live a certain lifestyle which is often expensive and unsustainable
#     - gender affirmative care is often provided at inflated costs
# - The article argues that the western notion that capitalism is inherently bad for queer people is too simplistic
#     - capitalism allowed queer communities in Asia to grow within authoritarian regimes

# %% [markdown]
# ### 26Feb25 Class
# - Group discussion
#     - relationship between capitalism and queer identity
#         - forces (western style) queer identities onto non western cultures
#         - relative levels of acceptance and suppression oscillate based on profitability due to sociopolitical climate
#         - queer people tend to be radical, anticapitalist, and anti-homonormative
#         - capitalism in some ways allowed for the formation of the queer identity
#         - in some regions it allows queer community to form and grow despite authoritarian regimes
#         - capitalism may cater to the queer community
#             - also tends to create an idealized and expensive queer lifestyle
#             - i.e. quantizes and commodifies the queer spectrum(s) into discrete labels (which clearly need special products!)
#         - contradictions
#             - capitalism benefits from childless income
#             - it is harmed by a lack of future income from children
#     - pink capitalism vs rainbow capitalism
#         -rainbow capitalism
#             - rainbow capitalism is more surface level
#                 - e.g. throwing rainbows and pride slogans on products
#             - e.g. Starbucks goes rainbow for June
#             - extracts money from the community
#             - uses LGBTQ+ symbols and language to sell products
#             - related to items/products/services
#             - more by and for queer people
#         - pink capitalism
#             - more discrete for a business
#                 - e.g. you may never know a bar was a gay bar until you go there and maybe even have to look or be told
#             - at least seems to be more about the community in the marketing
#             - more commited, i.e. not just in June
#             - less focused on labeling or creating labels for people to fit into
#             - recirculates money within the community more than rainbow capitalism
#                 - still extracts money
#             - related to spaces and events
#             - can still create and enforce categories
#                 - overall, can still fall into the same traps as rainbow capitalism
#         - wrapup
#             - difficult topic for some if not most groups to fully differentiate
#             - pink capitalism is still exploitative but may be more community oriented and circulate capital within the community, but mostly as a side effect
#             - pink capitalism is more locally focused while rainbow capitalism is more nationally or globally focused
#             - rainbow capitalism "celebrates" [homonormative, eurocentric] queerness
#             - there are exceptions to both and overlap between them in specific contexts

# %% [markdown]
# ### 27Feb25 Readings
# #### Disidentifications (Jose Esteban Munoz)
# - **dense**
# - disidentification:
#     - "disidentification is meant to be descriptive of the survival strategies the minority subject practices in order to negotiate a phobic majoritarian public sphere that continuously elides or punishes the existence of subjects who do not conform to the phantasm of normative citizenship"
# - Jack Smith
#     - queer theater artist
#     - used and subverted tropes such as exiticism and orientalism as a social critique
#     - believed that art can and should be used as a tool for education and change
# - performance art is supposed to change the way the audience views the world

# %% [markdown]
# ### 28Feb25 Class
# - close reading: fine grain analysis of a specific topic, section, or word in a text
# - disidentification: "a descriptive of the survival strategies the minority subject practices in order to negotiate a phobic majoritarian public sphere that continuously elides or punishes the existence of subjects who do not conform to the phantasm of normative citizenship"
#     - break it down:
#         - the "minority subject"
#             - the group of least power who calls outside the norm
#         - "phobic majoritian public sphere"
#             - the normative public society which oppresses the minority subject to enforce the normative ideal
#         - the "phantasm of normative citizenship"
#             - the normative ideal
#             - it is phantasmal because it isn't real, tangible, or attainable
#     - in english: disidentification describes the behaviors which marginalized people must undertake to survive more comfortably in a normative society that they do not otherwise conform to
# - subject construction vs ideological practices
#     - identification, counteridentification, disidentification
#         - forming an identity, defining what one is, inherently requires counteridentification, defining what one isn't
#         - identification generally involves evaluating a laundry list of different markers/behaviors/etc to decide whether they do or do not represent us and our desired identity
#         - disidentification is then about redefining and re-contextualizing these identifying markers
#             - an active and deliberate choice
#             - incorporates both identification and disidentification
#             - instead of trying to counter the toxic parts of an identity marker, it acknowledges them and attempts to transform them into something positive or otherwise more accurate

# %% [markdown]
# ### 02Mar25 Readings
# #### Of Fish and Feminists (Laurie Norris)
# - key terms: (as I understand them from the reading and light googling)
#     - fishy: a term used in drag culture to describe a queen who looks like a cisgender woman
#         - seems to have extremely offensive roots
#         - seems to have been normalized by mostly unknown drag queens over time
#         - now seems to be being phased out in some circles
#             - no date is given to this essay but the book was published in 2014
#     - Real Fish: a noun referring to queens who employ a drag style which is more realistic and less exaggerated
#         - used in this article as a noun for "fishy" queens
#     - High Drag: a style which is more exaggerated and less realistic
#         - not used explicitly in this article but I believe it is the what the article refers to when it discusses the pageant style of drag
# - heteronormativity and homonormativity both privilege stereotypical masculinity and other heteronormative ideals at the expense of other identities
#     - e.g. women, people of color, etc.
#     - homonormativity "aim[s] at securing privileges for gender-normative gays and lesbians based on adherence to dominant cultural constructions of gender, and it diminish[es] the scope of potential resistance to oppression."
#         - Susan Stryker
#         - i.e., it is a form of assimilation which reinforces the status quo
#     - Eve Ng suggests that *RuPaul's Drag Race* provides the Logo cable network with a way to pacify calls for more queer representation in media while also appealing to some straight audiences
# - *Drag Race*
#     - within the show, a certain type of drag is privileged
#         - most successful queens come from the competitive circuit and style themselves in the pageant style
#         - other styles are often portrayed as less legitimate
#             - these participants are often eliminated early
#             - they are often portrayed as less serious or less talented
#             - they are also often portrayed as being bullied by the "real" queens
#     - the show parodies *America's Next Top Model* and similar shows
#         - in some ways it is a critique of them
#         - in others it reinforces the same types norms on a new group of people
# - Norris notes that within the Imperial Court System of Spokane, a drag organization, a hierarchy exists granting validity on certain types of drag
#     - the pecking order is as follows
#         - gay drag queens are seen as the most legitimate
#         - gay drag kings the next most
#         - lesbian drag kings follow
#         - lesbian drag queens are seen as the least legitimate
#     - interestingly, gay queens and lesbian kings are seen as more legitimate than their counterparts
#     - yet still gay drag performers are seen as more legitimate than lesbian drag performers regardless of their drag style
# - *Drag Race*'s evolution
#     - the show has begun to incorporate more diverse styles of drag
#     - some performers employing these styles have been successful and the "arc" and/or narrative around them has not focused on their style of drag
#     - still, as cited in the Tatianna "Villain Cut", editing has been used as a narrative tool at the expense of some queens and their styles
#         - in the companion series *Untucked*, transphobic comments are played for laughs at Tatiana's expense
#             - it is worth noting that Tatiana expresses that she is not transgender, so the comments seem even more out of nowhere
#     - use of the term "bitch"
#         - Norris suggests that the show acts as if the term has been reclaimed in a way similar to the way that "queer" has
#             - many people do not feel that this is accurate and that it contributes to homonormativity and continued misogyny

# %% [markdown]
# ### 03Mar25 Class
# - homonormativity
#     - still striving to maximize proximity to the center of the "circle of citizenship"
#         - it is still promoting
#             - monogamy
#                 - the expected relationship goal is marriage
#             - masculinity
#             - white supremacy
#             - class/wealth
#             - eurocentricism
#             - cisnormativity
#         - i.e. homonormativity is heteronormativity but you line-item-veto the heterosexuality requirement
# - misogyny and the term "bitch"
#     - drag race assumes that the term has been reclaimed but does not engage critically with implications of the term
#     - reclamation of a term must be done by the group who the term was used against
#         - drag queens are generally not the ones who should be reclaiming this term
#         - **when used by other groups, it isn't reclamation, it is misogyny**
#     - Rohin Guha notes that "gay streamed media" allows gay men to engage in a lot of misogyny and suggests that that is a part of the gay identity
#         - e.g. allows gay men to discuss revulsion towards women's bodies
#         - e.g. black trans women's "reading" each other being appropriated by gay men
#         - hides oppression by saying "this is a part of my identity as an oppressed person"
#             - suggests that the oppressive actions cannot be criticized because the criticism is (supposedly) oppressive
#             - implies that an oppressed group could not be an oppressor
#         - wrapped up in lots of things
#             - heteronormative notions of the "uncleanness" of women and specifically the vagina
#                 - say "penis" in a middle school, you get giggles
#                 - say "vagina" in a middle school, you get "eww"s
#     - a large portion of RuPaul's viewing audience is straight cis women
#         - reinforces the "gay best friend" dynamic
#         - gay men and straight women are both (at least) one step removed from the center of the circle
#             - allows both to look down on the other
#     - **how a term is used also determines whether it is oppressive**
#         - e.g. a woman calling another woman a bitch is still misogyny
#     - outside of feminist spaces, most misogyny goes uncommented on no matter who is perpetrating it
#         - it is often normalized
#         - it is often difficult to call out someone "higher" in the system of power
#     - when we do call it out
#         - to positively compare ourselves to other groups
#             - e.g. white people talking about communities of color
#             - e.g. (white) Americans talking about the Middle East
#         - usually not to, but about people in the room
#             - i.e. you are constructing a strawman who isn't in the room to defend itself
#                 - low or no risk
#                 - also allows contrary evidence to be "exceptions" that "don't count"

# %% [markdown]
# ### 04Mar25
# #### Performative Blackness and the Problem with 'RuPaul's Drag Race' (Kat Blaque)
# - Blaque argues that RuPaul feels at times like a "white man in blackface"
#     - by this they do not mean that RuPaul is necessarily racist
#     - RuPaul presents his race in a way that is palatable to white audiences
# - They discuss a drag performance they attended in New York which a former RuPaul performer was in
#     - they had a comedic bit which was written around 2 white men putting on stereotypical black clothing and wigs
#     - a similar theme was employed on a RuPaul episode where non-black queens were directed on how to act more black
# - RuPaul is a complex figure
#     - he has done a lot to advance the visibility of the LGBTQ+ community
#     - he has also made some questionable decisions and made jokes at the expense of other marginalized groups
# #### Summary: Gender Trouble / Judith Butler
# -

# %% [markdown]
# ### 05Mar25
# #### Paris Is Burning
# - concepts to revisit
#     - space
#     - history/evolution
#     - houses/family
#     - shade

# %% [markdown]
# ### 07Mar25
# - Performativity:
#     - "The attempt to emulate or subvert the unrealistic, constantly changing, and forever unattainable gender ideals that shape all of us individually and in our interactions with others" -- Dr. Batza
#         - `emulate or subvert`
#             - we can either try to meet or try to defy the "ideal" "norm"
#         - `constantly changing`/`forever unattainable`, `gender ideals`
#             - throughout history, the ideal has changed even on the timescale of a few years
#             - the ideal is also impossible to meet
#                 - even for those ostensibly closest to it or for whom the ideal was designed
#                     - hence it harms and oppresses everyone
#             - gender ideals: (not exhaustive, not accurate for all cultures, not accurate for all times)
#                 - both
#                     - cis
#                     - heterosexual
#                     - monogamous
#                 - man
#                     - tough
#                     - open body language
#                     - labor intensive work
#                     - authoritative
#                     - stoic & unemotional
#                     - leader, protector, provider
#                     - intelligent and capable
#                     - larger stature
#                     - loud, deep voice
#                     - boxier, looser clothing
#                     - hairy face and body, short (head) hair
#                     - not responsible for childcare
#                     - ...
#                 - woman
#                     - feminine
#                     - frilly
#                     - closed body language/taking up less space
#                     - less labor intensive work & house work
#                     - submissive
#                     - expected to be emotional
#                     - follower, victim, nurturer
#                     - less intelligent and capable
#                     - smaller stature
#                     - soft, high voice
#                     - more form fitting, revealing clothing
#                     - hairless face and body, long (head) hair
#                     - responsible for childcare
#                     - ...
#         - `shape all of us individually and in our interactions with others`
#             - even if we do not conform or subscribe to the ideal, it still affects us
# - performance vs performativity
#     - performance is a conscious act to follow or defy the ideal
#         - i.e. we all choose what to emulate from the above lists

# %% [markdown]
# ## Assignment 2: Sexuality in Context Paper
# - learn additional aspects of LGBTQ history and strengthen critical analysis of changes in the contextual definitions of gender and sexuality over time.
# - process:
#     - 1. Identify a person in LGBTQ history
#         - can also choose a place or event but this requires more effort and **generally doesn't work as well**
#     - 2. Analyze and explain how definitions and understandings of sexuality shaped that person
# - 3-4 ($\pm \frac{1}{4}$) page paper
#     - 2.75 pages is the minimum
#         - i.e. at least 3/4 of the way into the 3rd page
#     - 4.25 pages is the maximum
#         - i.e. not more than 1/4 of the way into the 5th page
#     - ~1 page identifying the chosen person
#     - ~1.5-2 pages analyzing and explaining how definitions and understandings of sexuality **at that time** shaped this person
#     - ~1 page
# - the links at the bottom of the instructions are US-centric as is the course but the assignment is not limited to the US
#     - caveat: if you choose someone in another country, make sure to **fully explain the context of the time and place**
# - formatting:
#     - 12pt Times New Roman
#     - 1 inch margins
#     - include name and title for the paper
#     - **do not include a header**
#         - e.g. instructor name, date, class,etc
#     - **use in text citations** following *a* standard
#         - e.g. MLA, APA, Chicago, etc
#         - if it's a weird one, reach out to verify it is acceptable
#         - uncited information is plagiarism
#             - as long as it is just a clear mistake, you'll get a 0 but be able to resubmit
# - can resubmit corrections based on feedback until the end of the semester
#
#
# #### Assignment 2: Sexuality in Context Paper
# Instructions, Rubric, and Example
#
# Instructions
# This assignment is designed to make you learn additional aspects of LGBTQ history and to strengthen your critical analysis of how gender and sexuality changes over time, is dependent upon location, and other identities and forces at work at any given moment.
#
# First identify a particular person (or place or event) in LBGTQ history. Once you’ve chosen your person (or place/event), explain and analyze how definitions and understandings of sexuality in that particular moment shaped that person (or place/event) Finally reflect upon the differences in historical and geographic contexts between your chosen person (or place/event) and the present day.
#
# This assignment requires you to write a 3 to 4-page paper. You should have a thesis, dedicate roughly 1 page to identifying your chosen person (or place/event), 1.5 – 2 pages analyzing and explaining how definitions and understandings of sexuality in that particular moment shaped your chosen person (or place/event), and 1 page reflecting upon differences between how sexuality was understood during the lifetime of your chosen person (or place/event) and present day.
#
# Feel free to use google or library database searches to research your person, place, or event.
#
# These links might also give you some ideas:
# US LGBTQ Timelines
# US LGBTQ Subjects
# US LGBTQ History Places
# US LGBTQ People
# National Park Service LGBTQ Theme Study
# GLSEN LGBTQ History Resource
#
#
# ### Rubric
#
# #### Identifying and explaining your chosen person/place/event: 15%
# This is largely a summary of your chosen person/place/event. However, you also need to provide some larger context about the time and place relating to your choice. I know a good bit about LGBTQ history, but I can’t know everything; consider this your one-page opportunity to teach me the important aspects of your chosen person/place/event.
#
# #### Analysis: 35%
# How have definitions and understandings of sexuality in that particular moment shaped your chosen person/place/event? Use the themes of the course to help you dig deeply and provide some strong analysis about what forces created this person/place/event.
#
# #### Reflection: 25%
# Reflect on the differences in historical and geographic contexts between your chosen person/place/event and the present day, connecting when possible with the course themes laid out in the class. Where have there been major shifts? What do those changes mean for LGBTQ folks today?
#
# #### Writing: 15%
# Writing should be clear, concise, and constructive. Make an argument! Is there a particular oppression, theme, social force that shapes your person/place/event? If so, that can be a great source of thesis inspiration! (Example: Martin Luther King Jr.’s choice to use peaceful protest stood in stark contrast to the violence most people of color faced in the United States during the 1960s.) Help your thesis along by providing supporting topic sentences for every paragraph afterward. Topic sentences should be the first sentence of every paragraph and should both introduce a new level of your analysis AND also help support your main thesis.
#
# #### Formatting and Citations: 10%
# Papers should be written in 12 pt. Times New Roman font unless cleared with the instructor. Page margins should be 1-inch on each side. Include your name and a title for your paper. You do NOT need to include any other headings (instructor name/date/class/etc.) or an abstract/title for your paper, but please follow a standard citation style for your parenthetical/“in-text” citations (e.g., APA, Chicago, MLA). If you need help with formatting your paper and citations, please ask me! I’m happy to help you.

# %% [markdown]
# ### 11Mar25 Readings
# #### Why Do We Only Love Genderbending When White Twinks Do It?
# - This article follows a similar theme to previous readings around hetero and homonormativity
# - the NYT has declared this the "age of the twink"
#     - this seems to be true at least for what forms of gender fluidity are being elevated in popular media
#     - white, straight, cis men with feminine presentation and dress are being celebrated
#     - at the same time, trans and queer people are being attacked and excluded
# - allowing some men to be feminine is progress but it is nowhere near enough
#     - women and nonbinary people of all body types, presentations, and identities must be afforded the same respect and celebration
# #### Greater transgender visibility hasn't helped nonbinary people – like me
# - our culture has an ingrained suspicion that gender nonconformity implies intent for harmful deception
# - while we are seeing greater trans visibility, nonbinary people are still largely ignored and misunderstood and discourse around trans individuals focuses passing and binary presentation
#     - these forms of representation challenge the idea that gender is innate but not that the binary is the only option

# %% [markdown]
# ### 12Mar25 Class
# #### gender performance
# - Hijras and Drag Queens reading
#     - Culture:
#         - drag is not built into our culture
#         - Hijras are a part of Indian culture and have been for a long time
#         - Hijras challenge the gender binary but not the cultural understanding of gender
#     - Reproduction:
#         - Hijras are unable to have children and this is seen as a fundamental part of their identity
#         - drag generally doesn't imply an ability/inability to reproduce
#             - it is not seen as a responsible or healthy parenting choice
#     - Identity vs Performance:
#         - Hijra is a gender identity
#         - drag is a performance
#             - i.e. generally one goes home and takes off the makeup and clothing until the next performance
# - Why Do We Only Love Genderbending When White Twinks Do It?
#     - we accept genderbending when the people are already very close to ideal citizens
#         - particularly the people are usually very conventionally attractive
#         - and almost exclusively men and white
#     - it is also usually a more explicit performance or publicity stunt and not an identity
#         - i.e. its something which these men can dabble in or "play" with and then leave behind
# - Greater Transgender Visibility Hasn't Helped Nonbinary People – Like Me
#     - everything is still about being able to put people into boxes
#         - e.g. someone who is nonbinary is "supposed" to be androgynous

# %% [markdown]
# ### 13Mar25 Readings
# #### Sexuality, History, and Britain’s Colonial Legacy
# - the British Empire exported its ideas about sexuality when it colonized places like Jamaica
#     - the conditions under which it was considered morally acceptable to engage in sexual activity was predominantly defined and debated by religious officials
#     - these religious philosophies were enshrined in law in various ways where possible and tended to disproportionately affect the poor and marginalized
# - these ideas had to be modified to fit the economic and social conditions constructed in the colonies
#     - in cases of indentured servitude
#         - authorities prohibited marriage among indentured servants so that a servant husband could not lay claim to his servant wife's labor
#         - pregnancy would result in a servant owing more time to their master to cover the cost of pregnancy and childcare
#     - the shift to slavery
#         - the masters' property rights to a slave extended to their children
#         - as the slave trade grew, the legal framework shifted from English common law to a more explicitly racist and oppressive system based on animal husbandry and property law
#         - where colonizers had avoided sexual activity with servants due to the financial burden of children, they now encouraged it with slaves to increase their property holdings
#         - in 1761 Jamaica passed a law making it illegal for white fathers to bequeath their property to their mixed race children to prevent the dilution of white wealth
#     - after slavery
#         - the change in the social and legal frameworks for defining the legitimacy of children continued to be a tool for oppression
#         - following the abolition of slavery, the rates of children born out of wedlock were used to measure how "civilized" the population was
#             - here again, African "promiscuity" was used to other and oppress
#         - even as people of color began to own property, they too were forced to participate in the same oppressive systems and perpetuate the same oppressive ideas
#         - sexism played a heavy role as well with the blame for illegitimate children falling heavily on the mother
#             - sexism, racism, classism all came into play to pit the oppressed against each other and protect those in power
#                 - again we see proximity to the center of the circle of citizenship weaponized to protect abusers and the status quo
# #### The idea that African homosexuality was a colonial import is a myth
# - a pervasive myth in Africa is that homosexuality did not exist before colonialism
#     - American evengelicals have helped to perpetuate this myth and to spread homophobia in Africa
# - homosexuality has been recorded by Europeans in Africa since at least the 16th century
#     - early explorers noted a number of different sexual practices and identities across Africa
#     - rock paintings in Zimbabwe from thousands of years ago depict anal sex between men
# - Christian and Islamic forces did not bring homosexuality to the African continent, they brough homophobia
#     - they *did* corrupt and pollute a rich tapestry of cultures and practices
#         - Not by bringing in homosexuality, but by destroying and oppressing the diverse people and cultures they encountered and enforcing their own narrow minded views
# - **See the below discussion of the lensing of this article**

# %% [markdown]
# ### 14Mar25 Class
# - readings
#     - criticizing the lens of the second reading
#         - the author is projecting their own modern understanding of homosexuality as an identity onto the past
#         - the examples cited would not fit this modern definition
#             - i.e. the people at the times would likely not identify with this modern definition
#             - the acts and identities are contextual to their time and place
#             - they already had a cultural understanding of these acts and identities
#         - another way of framing it
#             - pre colonial african cultures had their own "boxes" for these acts and identities
#             - colonial powers forced these acts into their own boxes
#             - the author tries to use the existence of the acts in the past as evidence for the existence for these colonial boxes
#                 - this continues to ignore the original boxes
#                 - hence it does not actually give legitimacy to the original identities, it just argues the legitimacy of eurocentric identities
#         - through this framing, homosexuality (and homophobia) actually was imported through colonialism
#             - this western understanding of homosexuality and the categorization of acts into boxes was imported
#             - the existing understanding was largely erased and vilified
#     - beware pieces which place western understandings of sexualities, identities, and other concepts in and from other cultures
